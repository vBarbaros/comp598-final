# %%
import json
from twitter_stats_utils import read_from_json

dict_stats = read_from_json('data/results/stats_per_label.json')
print(json.dumps(dict_stats, indent=4))
# Out:
# {
#     "sentiment": {
#         "pos": [
#             344,
#             "0.3440"
#         ],
#         "neg": [
#             489,
#             "0.4890"
#         ],
#         "neut": [
#             167,
#             "0.1670"
#         ],
#         "sum": 1000
#     },
#     "labels": {
#         "covid-controversy": [
#             338,
#             "0.3380"
#         ],
#         "covid-new-variant": [
#             66,
#             "0.0660"
#         ],
#         "pandemic-legal": [
#             146,
#             "0.1460"
#         ],
#         "covid-logistics": [
#             264,
#             "0.2640"
#         ],
#         "vax-efficiency": [
#             186,
#             "0.1860"
#         ],
#         "sum": 1000
#     },
#     "ca-related": {
#         "ca": [
#             288,
#             "0.2880"
#         ],
#         "non-ca": [
#             264,
#             "0.2640"
#         ],
#         "na": [
#             448,
#             "0.4480"
# ...

# %%
dict_stats = read_from_json('data/results/stats_per_day.json')
print(json.dumps(dict_stats, indent=4))
# Out:
# {
#     "29_nov": {
#         "filter-type": {
#             "gvnmt": [
#                 50,
#                 "0.1667"
#             ],
#             "keyword": [
#                 200,
#                 "0.6667"
#             ],
#             "news": [
#                 50,
#                 "0.1667"
#             ],
#             "sum": 300
#         },
#         "ca-related": {
#             "ca": [
#                 95,
#                 "0.3167"
#             ],
#             "non-ca": [
#                 105,
#                 "0.3500"
#             ],
#             "na": [
#                 100,
#                 "0.3333"
#             ],
#             "sum": 300
#         },
#         "sentiment": {
#             "pos": [
#                 93,
#                 "0.3100"
#             ],
#             "neg": [
#                 166,
#                 "0.5533"
#             ],
#             "neut": [
#                 41,
#                 "0.1367"
#             ],
# ...
